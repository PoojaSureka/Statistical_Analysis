# %%
data = [23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data2 = pd.read_csv("Iris.csv")

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data3 = pd.read_csv("Titanic.csv")

# %%
data3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.mean(data_copy)
# Out:
# 37.36363636363637

# %%
np.median(data_copy)
# Out:
# 32.0

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
np.mean(data2["SepalLengthCm"])
# Out:
# 5.843333333333334

# %%
np.median(data2["SepalLengthCm"])
# Out:
# 5.8

# %%
import statistics

# %%
statistics.mode(data)
# Out:
# 32

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sum = 0

for i in data:
    sum = sum+i
mean = sum/len(data)
print(mean)
# Out:
# 37.36363636363637

# %%
def mean(data):
    sum = 0
    for i in data:
        sum = sum+i
    mean = sum/len(data)
    return mean

# %%
mean(data)
# Out:
# 37.36363636363637

# %%
from scipy import stats as st
st.mode(data)
# Out:
# C:\Users\psure\AppData\Local\Temp\ipykernel_19824\3794622683.py:2: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   st.mode(data)
# ModeResult(mode=array([32]), count=array([3]))

# %%
data_copy.append(150)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
np.mean(data_copy)
# Out:
# 46.75

# %%
np.median(data_copy)
# Out:
# 37.5

# %%
np.mean(data)
# Out:
# 37.36363636363637

# %%
np.median(data)
# Out:
# 32.0

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data.sort()

# %%
data_copy2 = data.copy()

# %%
data_copy2.append(75)

# %%
data_copy2
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 75]

# %%
np.mean(data_copy2)
# Out:
# 40.5

# %%
np.median(data_copy2)
# Out:
# 37.5

# %%
### dispersion

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.percentile(data, [25])
# Out:
# array([28.])

# %%
np.percentile(data, [50])
# Out:
# array([32.])

# %%
### min, q1 = 25, q2 = 50, q3 = 75, max
### IQR = Q3-Q1

### lower fence = q1 - iqr*1.5
### upper fence = q3 + iqr*1.5

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.percentile(data, [25,50,75,100])
# Out:
# array([28., 32., 45., 67.])

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(150)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
sns.boxplot(data_copy)
# Out:
# <Axes: >

# %%
### variance
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.random.choice(data, size = 3)
# Out:
# array([12, 32, 32])

# %%
data2.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 94    95            5.6           2.7            4.2           1.3
# 50    51            7.0           3.2            4.7           1.4
# 12    13            4.8           3.0            1.4           0.1
# 121  122            5.6           2.8            4.9           2.0
# 85    86            6.0           3.4            4.5           1.6
#
#              Species
# 94   Iris-versicolor
# 50   Iris-versicolor
# 12       Iris-setosa
# 121   Iris-virginica
# 85   Iris-versicolor

# %%
"""
def variance(data):
    n = len(data)
    mean = sum(data)/n
    deviation = [(x-mean) ** 2 for x in data]
    variance = sum(deviation)/(n)
    return variance
    """
# Out:
# '\ndef variance(data):\n    n = len(data)\n    mean = sum(data)/n\n    deviation = [(x-mean) ** 2 for x in data]\n    variance = sum(deviation)/(n)\n    return variance\n    '

# %%
np.var(data)
# Out:
# 226.23140495867767

# %%
np.std(data)
# Out:
# 15.040990823701664

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
import statistics

# %%
### using n-1
statistics.variance(data)
# Out:
# 248.85454545454544

# %%
### using n
statistics.pvariance(data)
# Out:
# 226.23140495867767

# %%
### standard deviation
import math
math.sqrt(statistics.variance(data))
# Out:
# 15.775124261144361

# %%
### standard deviation
import math
math.sqrt(statistics.pvariance(data))
# Out:
# 15.040990823701664

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
len(data)
# Out:
# 11

# %%
### correlation and covariance

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
### pearson correlation
df.corr
# Out:
# <bound method DataFrame.corr of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df.corr()
# Out:
# C:\Users\psure\AppData\Local\Temp\ipykernel_19824\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.pairplot(df)

# %%
sns.scatterplot(data = df, x = "size", y = "tip")
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.scatterplot(data = df, x = "total_bill", y = "tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
### covariance
df.cov()
# Out:
# C:\Users\psure\AppData\Local\Temp\ipykernel_19824\3721443240.py:2: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
### pdf

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data.sort()

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(data = data2, x = "SepalLengthCm", kde = True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data = data2, x = "SepalWidthCm", kde = True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data = data2, x = "PetalLengthCm", kde = True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(data = data2, x = "PetalWidthCm", kde = True)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(179)

# %%
data_copy.append(210)

# %%
data_copy.append(289)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 289]

# %%
sns.histplot(data_copy, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy2
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 75]

# %%
data_copy2[0] = -10

# %%
data_copy2
# Out:
# [-10, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 75]

# %%
data_copy2[1] = -75

# %%
data_copy2
# Out:
# [-10, -75, 24, 32, 32, 32, 43, 45, 45, 56, 67, 75]

# %%
sns.histplot(data_copy2, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
s = np.random.normal(0.5,0.2,1000)

# %%
sns.histplot(s, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
s1 = np.random.normal(0,1,1000)
sns.histplot(s, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
### mu = mean, sigma = standard deviation
p = np.random.lognormal(3.0,1.0,1000)

# %%
sns.histplot(p, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
### converting log normal into normal distribution
sns.histplot(np.log(p), kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data = data2, x = "SepalLengthCm", kde = True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(np.log(data2["SepalLengthCm"]), kde = True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data = data2, x = np.log(data2["SepalLengthCm"]), kde = True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize = (10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample, kde = True)
    plt.subplot(1,2,2)
    stat.probplot(sample, dist = "norm", plot = pylab)
    plt.show()

# %%
plot_data(data)

# %%
plot_data(data_copy)

# %%
plot_data(s)

# %%
plot_data(p)

# %%
plot_data(np.log(p))

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plot_data(data2["PetalLengthCm"])

# %%
data3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Pandas Profiling

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(data3)
prof.to_file(output_file="output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
